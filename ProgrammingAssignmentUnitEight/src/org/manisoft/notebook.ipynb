# %%
import pandas as pd

# %%
df = pd.read_csv("EmployeeSampleData1.csv")
df
# Out:
#    Employee ID          Full Name                 Job Title  Department  \
# 0       E02007            Ezra Vu     Network Administrator          IT
# 1       E02023      Lillian Lewis       Technical Architect          IT
# 2       E02038   Amelia Dominguez               Sr. Manager  Accounting
# 3       E02043       Gianna Jones                   Manager  Accounting
# 4       E02060        Jacob Cheng                  Director       Sales
# ..         ...                ...                       ...         ...
# 86      E02758         Sadie Pham                Analyst II     Finance
# 87      E02770        Iris Bailey            IT Coordinator          IT
# 88      E02776  Caroline Sandoval                   Manager     Finance
# 89      E02848      Clara Collins          Network Engineer          IT
# 90      E02851        Piper Evans  Computer Systems Manager          IT
#
#              Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# ...

# %%
df["Annual Salary"] = df["Annual Salary"].str.strip().str.replace("$", "").str.replace(",", "")
df
# Out:
#    Employee ID          Full Name                 Job Title  Department  \
# 0       E02007            Ezra Vu     Network Administrator          IT
# 1       E02023      Lillian Lewis       Technical Architect          IT
# 2       E02038   Amelia Dominguez               Sr. Manager  Accounting
# 3       E02043       Gianna Jones                   Manager  Accounting
# 4       E02060        Jacob Cheng                  Director       Sales
# ..         ...                ...                       ...         ...
# 86      E02758         Sadie Pham                Analyst II     Finance
# 87      E02770        Iris Bailey            IT Coordinator          IT
# 88      E02776  Caroline Sandoval                   Manager     Finance
# 89      E02848      Clara Collins          Network Engineer          IT
# 90      E02851        Piper Evans  Computer Systems Manager          IT
#
#              Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# ...

# %%
df.dtypes
# Out:
# Employee ID      object
# Full Name        object
# Job Title        object
# Department       object
# Business Unit    object
# Gender           object
# Ethnicity        object
# Age               int64
# Hire Date        object
# Annual Salary    object
# Bonus %          object
# Country          object
# City             object
# Exit Date        object
# dtype: object

# %%
df["Annual Salary"] = pd.to_numeric(df["Annual Salary"])

# %%
df
# Out:
#    Employee ID          Full Name                 Job Title  Department  \
# 0       E02007            Ezra Vu     Network Administrator          IT
# 1       E02023      Lillian Lewis       Technical Architect          IT
# 2       E02038   Amelia Dominguez               Sr. Manager  Accounting
# 3       E02043       Gianna Jones                   Manager  Accounting
# 4       E02060        Jacob Cheng                  Director       Sales
# ..         ...                ...                       ...         ...
# 86      E02758         Sadie Pham                Analyst II     Finance
# 87      E02770        Iris Bailey            IT Coordinator          IT
# 88      E02776  Caroline Sandoval                   Manager     Finance
# 89      E02848      Clara Collins          Network Engineer          IT
# 90      E02851        Piper Evans  Computer Systems Manager          IT
#
#              Business Unit  Gender  Ethnicity  Age   Hire Date  Annual Salary  \
# ...

# %%
df["Hire Date"] = pd.to_datetime(df["Hire Date"], format="mixed")
df
# Out:
#    Employee ID          Full Name                 Job Title  Department  \
# 0       E02007            Ezra Vu     Network Administrator          IT
# 1       E02023      Lillian Lewis       Technical Architect          IT
# 2       E02038   Amelia Dominguez               Sr. Manager  Accounting
# 3       E02043       Gianna Jones                   Manager  Accounting
# 4       E02060        Jacob Cheng                  Director       Sales
# ..         ...                ...                       ...         ...
# 86      E02758         Sadie Pham                Analyst II     Finance
# 87      E02770        Iris Bailey            IT Coordinator          IT
# 88      E02776  Caroline Sandoval                   Manager     Finance
# 89      E02848      Clara Collins          Network Engineer          IT
# 90      E02851        Piper Evans  Computer Systems Manager          IT
#
#              Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
df.to_csv("EmployeeSampleData1.csv", index=False)

# %%
df["Exit Date"] = pd.to_datetime(df["Exit Date"], format="mixed")
df
# Out:
#    Employee ID          Full Name                 Job Title  Department  \
# 0       E02007            Ezra Vu     Network Administrator          IT
# 1       E02023      Lillian Lewis       Technical Architect          IT
# 2       E02038   Amelia Dominguez               Sr. Manager  Accounting
# 3       E02043       Gianna Jones                   Manager  Accounting
# 4       E02060        Jacob Cheng                  Director       Sales
# ..         ...                ...                       ...         ...
# 86      E02758         Sadie Pham                Analyst II     Finance
# 87      E02770        Iris Bailey            IT Coordinator          IT
# 88      E02776  Caroline Sandoval                   Manager     Finance
# 89      E02848      Clara Collins          Network Engineer          IT
# 90      E02851        Piper Evans  Computer Systems Manager          IT
#
#              Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
df.to_csv("EmployeeSampleData1.csv", index=False)
